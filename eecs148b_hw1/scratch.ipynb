# %%
from datasets import load_dataset

ds = load_dataset("roneneldan/TinyStories")
# Out:
# ...
# README.md: 0.00B [00:00, ?B/s]
# data/train-00000-of-00004-2d5a1467fff108(…):   0%|          | 0.00/249M [00:00<?, ?B/s]
# Cancellation requested; stopping current tasks.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# File ~/anaconda3/envs/be206/lib/python3.11/site-packages/huggingface_hub/file_download.py:558, in xet_get(incomplete_path, xet_file_data, headers, expected_size, displayed_filename, tqdm_class, _tqdm_bar)
#     556     progress.update(progress_bytes)
# --> 558 download_files(
#     559     xet_download_info,
#     560     endpoint=connection_info.endpoint,
#     561     token_info=(connection_info.access_token, connection_info.expiration_unix_epoch),
#     562     token_refresher=token_refresher,
#     563     progress_updater=[progress_updater],
#     564     request_headers=xet_headers,
#     565 )
#
# KeyboardInterrupt:
#
# ...
